# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import re
import pprint as pp
import datetime
import pathlib


filename = "/Users/dgrosz/Documents/PayPal/testData/IrisDB_large1.csv" #must insert absolute filepath
f_b = filename[:filename.rfind("/")]
d_b = filename[filename.rfind("/"):filename.rfind(".")]
VIZ_PATH = f_b + d_b + "_Viz_Stats/"
pathlib.Path(VIZ_PATH).mkdir(exist_ok=True)
print(VIZ_PATH)
# Out:
# /Users/dgrosz/Documents/PayPal/testData/IrisDB_large1_Viz_Stats/

# %% [markdown]
# If a filename is provided and it is a CSV, the data will be loaded into X. If not, a random numerical dataset with one column of some missing data will be loaded.

# %%
def read_data(filename):
# to test with clean numerics
    if len(filename) == 0:
        sz = 50000
        X = pd.DataFrame(np.random.randint(0,100,size=(sz, 23)), columns=list('ABCDEFGHIJMNOPQRSTUVWXY'))
        nans = [1, np.nan] * int(sz / 2)
        Y = pd.DataFrame(nans, columns=list('Z'))
        X = pd.concat([X, Y], axis=1, sort=False)
        return X
    else:
        # to test with command line arg
        return pd.read_csv(filename, parse_dates=True)

    
print("Reading data...")
X = read_data(filename)
print("Data is read.")
X
# Out:
# Reading data...
# /Users/dgrosz/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2903: DtypeWarning: Columns (8,14,21,42,57,58,59,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# Data is read.
#            display_dt      Status  Number of Records  TTA_min  TTA_notnull  \
# 0        6/1/18 11:14         new                1.0   0.0000          0.0
# 1        6/1/18 11:14         new                1.0   0.0000          0.0
# 2         6/1/18 9:31     expired                1.0   0.0000          0.0
# 3         6/1/18 9:31     expired                1.0   0.0000          0.0
# 4        6/1/18 10:13     expired                1.0   0.0000          0.0
# 5        6/1/18 10:43     expired                1.0   0.0000          0.0
# 6        6/1/18 10:37     expired                1.0   0.0000          0.0
# 7        6/1/18 11:13     expired                1.0   0.0000          0.0
# 8        6/1/18 12:02     expired                1.0   0.0000          0.0
# 9        6/1/18 12:02     expired                1.0   0.0000          0.0
# 10       6/1/18 13:02     expired                1.0   0.0000          0.0
# 11       6/1/18 14:45     expired                1.0   0.0000          0.0
# 12       6/1/18 14:45     expired                1.0   0.0000          0.0
# 13       6/1/18 14:45     expired                1.0   0.0000          0.0
# 14       6/1/18 14:45     expired                1.0   0.0000          0.0
# 15       6/1/18 14:45     expired                1.0   0.0000          0.0
# 16       6/1/18 14:45     expired                1.0   0.0000          0.0
# 17       6/1/18 14:45     expired                1.0   0.0000          0.0
# 18       6/1/18 14:45     expired                1.0   0.0000          0.0
# 19       6/1/18 14:45     expired                1.0   0.0000          0.0
# 20       6/1/18 14:45     expired                1.0   0.0000          0.0
# 21       6/1/18 14:45     expired                1.0   0.0000          0.0
# 22       6/1/18 14:45     expired                1.0   0.0000          0.0
# 23       6/1/18 14:45     expired                1.0   0.0000          0.0
# 24       6/1/18 14:45     expired                1.0   0.0000          0.0
# 25       6/1/18 14:45     expired                1.0   0.0000          0.0
# 26       6/1/18 14:45     expired                1.0   0.0000          0.0
# 27       6/1/18 14:45     expired                1.0   0.0000          0.0
# 28       6/1/18 14:45     expired                1.0   0.0000          0.0
# ...                       ...
# 235994                    NaN
# 235995                    NaN
# 235996                    NaN
# 235997                    NaN
# 235998                    NaN
# 235999                    NaN
# 236000                    NaN
# 236001                    NaN
# 236002                    NaN
# 236003  sherlock-alert-module
# 236004                    NaN
# 236005                    NaN
# 236006                    NaN
# 236007                    NaN
# 236008                    NaN
# 236009                    NaN
# 236010                    NaN
# 236011  sherlock-alert-module
# 236012                    NaN
# 236013                    NaN
# 236014                    NaN
# 236015                    NaN
# 236016                    NaN
# 236017                    NaN
# 236018                    NaN
# 236019                    NaN
# 236020                    NaN
# 236021  sherlock-alert-module
# 236022                    NaN
# 236023                    NaN
#
#                               ...                         tags tally  \
# 0                             ...                          NaN   1.0
# 1                             ...                          NaN   2.0
# 2                             ...                          NaN   1.0
# 3                             ...                          NaN   1.0
# 4                             ...                          NaN   1.0
# 5                             ...                          NaN   1.0
# 6                             ...                          NaN   4.0
# 7                             ...                          NaN   1.0
# 8                             ...                          NaN   1.0
# 9                             ...                          NaN   2.0
# 10                            ...                          NaN   1.0
# 11                            ...                          NaN   1.0
# 12                            ...                          NaN   1.0
# 13                            ...                          NaN   1.0
# 14                            ...                          NaN   1.0
# 15                            ...                          NaN   1.0
# 16                            ...                          NaN   1.0
# 17                            ...                          NaN   1.0
# 18                            ...                          NaN   1.0
# 19                            ...                          NaN   1.0
# 20                            ...                          NaN   1.0
# 21                            ...                          NaN   1.0
# 22                            ...                          NaN   1.0
# 23                            ...                          NaN   1.0
# 24                            ...                          NaN   4.0
# 25                            ...                          NaN   1.0
# 26                            ...                          NaN   1.0
# 27                            ...                          NaN   1.0
# 28                            ...                          NaN   1.0
# 29                            ...                          NaN   1.0
# ...                           ...                          ...   ...
# 235994                        ...                          NaN   1.0
# 235995                        ...                          NaN   1.0
# 235996                        ...                          NaN   1.0
# 235997                        ...                          NaN   1.0
# 235998                        ...                          NaN   1.0
# 235999                        ...                          NaN   1.0
# 236000                        ...                          NaN   1.0
# 236001                        ...                          NaN   1.0
# 236002                        ...                          NaN   1.0
# 236003                        ...                          NaN   1.0
# 236004                        ...                          NaN   1.0
# 236005                        ...                          NaN   1.0
# 236006                        ...                          NaN   1.0
# 236007                        ...                          NaN   1.0
# 236008                        ...                          NaN   1.0
# 236009                        ...                          NaN   2.0
# 236010                        ...                          NaN   2.0
# 236011                        ...                          NaN   1.0
# 236012                        ...                          NaN   1.0
# 236013                        ...                          NaN   1.0
# 236014                        ...                          NaN   1.0
# 236015                        ...                          NaN   1.0
# 236016                        ...                          NaN   1.0
# 236017                        ...                          NaN   1.0
# 236018                        ...                          NaN   2.0
# 236019                        ...                          NaN   2.0
# 236020                        ...                          NaN   2.0
# 236021                        ...                          NaN   2.0
# 236022                        ...                          NaN   1.0
# 236023                        ...                          NaN   NaN
#
#            ticket_ts    ticketid ticketsystem           ticketuid  \
# 0                NaN         NaN          NaN                 NaN
# 1                NaN         NaN          NaN                 NaN
# 2                NaN         NaN          NaN                 NaN
# 3                NaN         NaN          NaN                 NaN
# 4                NaN         NaN          NaN                 NaN
# 24                     NaN       NaN       NaN
# 25                     NaN       NaN       NaN
# 26                     NaN       NaN       NaN
# 27                     NaN       NaN       NaN
# 28                     NaN       NaN       NaN
# 29                     NaN       NaN       NaN
# ...                    ...       ...       ...
# 235994                 NaN       NaN       NaN
# 235995                 1.0       NaN       NaN
# 235996                 NaN       NaN       NaN
# 235997               598.0       NaN       NaN
# 235998               598.0       NaN       NaN
# 235999               598.0       NaN       NaN
# 236000                 NaN       NaN       NaN
# 236001                 NaN       NaN       NaN
# 236002                 NaN       NaN       NaN
# 236003               598.0       NaN       NaN
# 236004                 NaN       NaN       NaN
# 236005                 NaN       NaN       NaN
# 236006                 NaN       NaN       NaN
# 236007                 NaN       NaN       NaN
# 236008                 NaN       NaN       NaN
# 236009               598.0       NaN       NaN
# 236010               598.0       NaN       NaN
# 236011               598.0       NaN       NaN
# 236012                 NaN       NaN       NaN
# 236013                 NaN       NaN       NaN
# 236014                 NaN       NaN       NaN
# 236015                 NaN       NaN       NaN
# 236016                 NaN       NaN       NaN
# 236017               598.0       NaN       NaN
# 236018                 NaN       NaN       NaN
# 236019                 NaN       NaN       NaN
# 236020                 NaN       NaN       NaN
# 236021                 NaN       NaN       NaN
# 236022                 NaN       NaN       NaN
# 236023                 NaN       NaN       NaN
#
#                                                       url
# 0        https://sherlock.paypalcorp.com/MySherlockApp...
# 1        https://sherlock.paypalcorp.com/MySherlockApp...
# 2       http://nyx.paypalcorp.com:443/reports/executio...
# 3       http://nyx.paypalcorp.com:443/reports/executio...
# 4       http://nyx.paypalcorp.com:443/reports/executio...
# 5       http://nyx.paypalcorp.com:443/reports/executio...
# 6       http://nyx.paypalcorp.com:443/reports/executio...
# 7       http://nyx.paypalcorp.com:443/reports/executio...
# 8       https://engineering.paypalcorp.com/condor/host...
# 9       https://engineering.paypalcorp.com/condor/host...
# 10      http://nyx.paypalcorp.com:443/reports/executio...
# 11      https://engineering.paypalcorp.com/condor/host...
# 12      https://engineering.paypalcorp.com/condor/host...
# 13      https://engineering.paypalcorp.com/condor/host...
# 14      https://engineering.paypalcorp.com/condor/host...
# 15      https://engineering.paypalcorp.com/condor/host...
# 16      https://engineering.paypalcorp.com/condor/host...
# 17      https://engineering.paypalcorp.com/condor/host...
# 18      https://engineering.paypalcorp.com/condor/host...
# 19      https://engineering.paypalcorp.com/condor/host...
# 20      https://engineering.paypalcorp.com/condor/host...
# 21      https://engineering.paypalcorp.com/condor/host...
# 22      https://engineering.paypalcorp.com/condor/host...
# 23      https://engineering.paypalcorp.com/condor/host...
# 24      https://engineering.paypalcorp.com/condor/host...
# 25      https://engineering.paypalcorp.com/condor/host...
# 26      https://engineering.paypalcorp.com/condor/host...
# 27      https://engineering.paypalcorp.com/condor/host...
# 28      https://engineering.paypalcorp.com/condor/host...
# 29      https://engineering.paypalcorp.com/condor/host...
# ...                                                   ...
# 235994                                                NaN
# 235995                                                NaN
# 235996  https://engineering.paypalcorp.com/sherlock/pp...
# 235997  https://engineering.paypalcorp.com/condor/apps...
# 235998  https://engineering.paypalcorp.com/condor/apps...
# 235999  https://engineering.paypalcorp.com/condor/apps...
# 236000  https://engineering.paypalcorp.com/condor/host...
# 236001  https://engineering.paypalcorp.com/condor/host...
# 236002  https://engineering.paypalcorp.com/condor/host...
# 236003  http://sherlock-qs-vip-b.slc.paypalinc.com/q?s...
# 236004                                                NaN
# 236005                                                NaN
# 236006                                                NaN
# 236007                                                NaN
# 236008                                                NaN
# 236009  https://engineering.paypalcorp.com/condor/apps...
# 236010  https://engineering.paypalcorp.com/condor/apps...
# 236011  http://sherlock-qs-vip-b.slc.paypalinc.com/q?s...
# 236012  https://engineering.paypalcorp.com/condor/apps...
# 236013  https://engineering.paypalcorp.com/condor/host...
# 236014  https://engineering.paypalcorp.com/condor/host...
# 236015  https://engineering.paypalcorp.com/condor/host...
# 236016  https://engineering.paypalcorp.com/condor/host...
# 236017  https://engineering.paypalcorp.com/condor/apps...
# 236018  http://appworx-vip.slc.paypal.com:8084/cgi-bin...
# 236019  http://appworx-vip.slc.paypal.com:8084/cgi-bin...
# 236020  http://appworx-vip.slc.paypal.com:8084/cgi-bin...
# 236021  https://engineering.paypalcorp.com/sherlock/gr...
# 236022  https://engineering.paypalcorp.com/condor/apps...
# 236023                                                NaN
#
# [236024 rows x 64 columns]

# %% [markdown]
# Going through each column, each column will be categorized as either a numerical or categorical column.
# A column is numerical if it the column's values have a numerical type and have more than 10 unique values or no unique values (this means it's only missing values and will be easier to clean out later). Numerical columns collect boxplot data (min-25%-median-75%-max) as well as non-null data count, missing data count, and standard deviation.
# A column is categorical if it is perceived as an object or category column by pandas or is numerical and has between 1 and 10 unique values. Categorical columns also collect non-null and null data counts. Mode, mode frequency, and number of unique values is also collected.
# For the entire dataset, row count, column count, missing data count, and missing data rate is collected.

# %%
def get_data_stats(X):
    df_stats_name = ["rows", "cols", "missing", "missing_rate"]
    df_stats_builder = [np.nan] * 4
    df_stats_builder[0], df_stats_builder[1] = int(X.shape[0]), int(X.shape[1])

    col_stats_name = ["count", "missing", "mean", "std", "min", "25%", "50%", "75%", "max", "unique", "top", "freq"]
    n_stats = len(col_stats_name)
    col_stats_toAppend = list(list())

    cat_data_valCounts = {}

    X_numeric, X_cat, X_date = pd.DataFrame(), pd.DataFrame(),pd.DataFrame()
    L_Xn, L_Xc, L_Xd = list(), list(), list()

    usable_col_names = list()
    for c in list(X):
        stat_c = [np.nan] * n_stats

        if X[c].dtype.name == 'category' or X[c].dtype.name == 'object':
            # is categorical
            stat_c = [X[c].count(), X[c].isnull().sum(), np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan,
                      X[c].nunique(), X[c].mode().iloc[0], X[c].value_counts().max()]
            isDate = False

            #Linearly comb through column to see if date
            for r in X[c]:
                try:
                    dt = datetime.datetime.strptime(str(r), "%m/%d/%y %H:%M")
                    isDate = True
                    break
                except ValueError:
                    if not str(r).lower() == "nan" and not str(r).lower() == "na" and re.search('[a-zA-Z]', str(r)):
                        break
                    pass  # do nothing
                try:
                    dt = datetime.datetime.strptime(str(r), "%m-%d-%y %H:%M")
                    isDate = True
                    break
                except ValueError:
                    continue  # skip to next
            if isDate:
                print("Column \"" + c + "\" is a DATE")
                print("Converting column...")
                X[c] = pd.to_datetime(X[c])
                L_Xd.append(c)
                stat_c = [X[c].count(), X[c].isnull().sum(), np.nan, np.nan, X[c].min(), np.nan, np.nan, np.nan,
                          X[c].max(), np.nan, X[c].mode().iloc[0], X[c].value_counts().max()]
                print("done")
            else:
                print("Column \"" + c + "\" is a CATEGORY")
                cat_data_valCounts[c] = X[c].value_counts()
                L_Xc.append(c)
            usable_col_names.append(c)
        elif (np.issubdtype(X[c].dtype, np.number)):
            # then is numerical
            print("Column \"" + c + "\" is a NUMERICAL")
            stat_c = [X[c].count(), X[c].isnull().sum(), X[c].mean(), X[c].std(), X[c].min(), X[c].quantile(.25),
                      X[c].median(), X[c].quantile(.75), X[c].max(), np.nan, np.nan, np.nan]
            n_unique = float(X[c].nunique())
            if n_unique > 10 or n_unique == 0:
                L_Xn.append(c)
            else:
                cat_data_valCounts[c] = X[c].value_counts()
                L_Xc.append(c)
                print("But column \"" + c + "\" is corrected to a CATEGORY because there are " + str(
                    int(n_unique)) + " unique numerical values.")
            usable_col_names.append(c)
        else:
            print("Column \"" + c + "\" is skipped because it is of an UNIDENTIFIED type.")
            print(X[c].dtype)
            continue
        col_stats_toAppend.append(stat_c)

    col_stats = pd.DataFrame(
        pd.DataFrame(data=col_stats_toAppend, columns=col_stats_name, index=usable_col_names)).transpose()

    for c in X:
        if c in L_Xn:
            X_numeric = pd.concat([X_numeric, X[c]], axis=1, sort=False)
        elif c in L_Xc:
            X_cat = pd.concat([X_cat, X[c]], axis=1, sort=False)
        elif c in L_Xd:
            X_date = pd.concat([X_date, X[c]], axis=1, sort=False)

    df_stats_builder[2] = int(col_stats.transpose()["missing"].sum())
    df_stats_builder[3] = float(df_stats_builder[2]) / (df_stats_builder[1] * df_stats_builder[0])
    df_stats = pd.DataFrame(np.array(df_stats_builder).reshape(1, 4), columns=df_stats_name)
    col_stats.to_csv(path_or_buf=VIZ_PATH + "COLUMN_STATS.csv")
    return X_numeric, X_cat, X_date, df_stats, col_stats, cat_data_valCounts

print("Getting stats...\n")
X_numeric, X_cat, X_date, df_stats, col_stats, cat_data_valCounts = get_data_stats(X)
print("\ndone.")
# Out:
# Getting stats...
#
# Column "display_dt" is a DATE
# Converting column...
# done
# Column "Status" is a CATEGORY
# Column "Number of Records" is a NUMERICAL
# But column "Number of Records" is corrected to a CATEGORY because there are 1 unique numerical values.
# Column "TTA_min" is a NUMERICAL
# Column "TTA_notnull" is a NUMERICAL
# But column "TTA_notnull" is corrected to a CATEGORY because there are 2 unique numerical values.
# Column "close_dt" is a DATE
# Converting column...
# done
# Column "ack_ts" is a NUMERICAL
# Column "ack_ts_notnull" is a NUMERICAL
# But column "ack_ts_notnull" is corrected to a CATEGORY because there are 2 unique numerical values.
# Column "ackuid" is a CATEGORY
# Column "agent" is a CATEGORY
# Column "alertid" is a CATEGORY
# Column "clear_ts" is a CATEGORY
# Column "cleartally" is a NUMERICAL
# Column "last_dt" is a DATE
# Converting column...
# done
# Column "close_message" is a CATEGORY
# Column "close_ts" is a NUMERICAL
# Column "closecode" is a NUMERICAL
# But column "closecode" is corrected to a CATEGORY because there are 8 unique numerical values.
# Column "closeuid" is a CATEGORY
# Column "colo" is a CATEGORY
# Column "component" is a CATEGORY

# %%
print("df_stats below")
print(df_stats)
# Out:
# df_stats below
#        rows  cols    missing  missing_rate
# 0  236024.0  64.0  5157076.0      0.341403

# %%
print("col_stats below")
print(col_stats)
# Out:
# col_stats below
#                   display_dt   Status Number of Records  TTA_min TTA_notnull  \
# count                 236023   236023            236023   236023      236023
# missing                    1        1                 1        1           1
# mean                     NaN      NaN                 1  3.99751    0.525606
# std                      NaN      NaN                 0  90.4298    0.499345
# min      2018-06-01 09:18:00      NaN                 1  -0.2833           0
# 25%                      NaN      NaN                 1        0           0
# 50%                      NaN      NaN                 1        0           1
# 75%                      NaN      NaN                 1   0.7667           1
# max      2018-06-28 13:02:00      NaN                 1  11279.9           1
# unique                   NaN        9               NaN      NaN         NaN
# top      2018-06-22 02:30:00  expired               NaN      NaN         NaN
# freq                   16678    96551               NaN      NaN         NaN
#
#                     close_dt       ack_ts ack_ts_notnull              ackuid  \
# count                 210555       124055         236023              124047
# missing                25469       111969              1              111977
# mean                     NaN  1.52907e+09       0.525606                 NaN
# std                      NaN       739285       0.499345                 NaN
# min      2018-06-01 09:20:00  1.52787e+09              0                 NaN
# 25%                      NaN  1.52836e+09              0                 NaN
# 50%                      NaN  1.52915e+09              1                 NaN
# 75%                      NaN  1.52971e+09              1                 NaN
# max      2018-06-28 13:00:00  1.53022e+09              1                 NaN
# unique                   NaN          NaN            NaN                 185
# top                      NaT          NaN            NaN  api_ppcc_sys_admin
# freq                    3321          NaN            NaN               51792
#
#                          agent  \
# count                    41032
# missing                 194992
# mean                       NaN
# std                        NaN
# min                        NaN
# 25%                        NaN
# 50%                        NaN
# 75%                        NaN
# max                        NaN
# unique                      33
# top      sherlock-alert-module
# freq                     28362
#
#                                ...                            tags    tally  \
# count                          ...                               0   236023
# missing                        ...                          236024        1
# mean                           ...                             NaN  11.5563
# std                            ...                             NaN  253.981
# min                            ...                             NaN        1
# 25%                            ...                             NaN        1
# 50%                            ...                             NaN        1
# 75%                            ...                             NaN        3
# max                            ...                             NaN    43277
# unique                         ...                             NaN      NaN
# top                            ...                             NaN      NaN
# freq                           ...                             NaN      NaN
#
#            ticket_ts    ticketid ticketsystem           ticketuid  \
# count          81232       80870        81251               80834
# missing       154792      155154       154773              155190
# mean     1.52905e+09         NaN          NaN                 NaN
# std           701453         NaN          NaN                 NaN
# min      1.52787e+09         NaN          NaN                 NaN
# 25%       1.5284e+09         NaN          NaN                 NaN
# 50%      1.52905e+09         NaN          NaN                 NaN
# 75%      1.52965e+09         NaN          NaN                 NaN
# max      1.53022e+09         NaN          NaN                 NaN
# unique           NaN       24618            1                 136
# top              NaN  INC0433791           SN  api_ppcc_sys_admin
# freq             NaN        1676        81251               41103
#
#         tot_alerts_per_tid                update_by    update_ts  \
# count                80870                      831          831
# missing             155154                   235193       235193
# mean               476.787                      NaN  1.52917e+09
# std                601.357                      NaN       594018
# min                      1                      NaN  1.52788e+09
# 25%                      1                      NaN  1.52875e+09
# 50%                     42                      NaN  1.52915e+09
# 75%                   1045                      NaN  1.52963e+09
# max                   1798                      NaN  1.53021e+09
# unique                 NaN                        1          NaN
NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 29           NaN         NaN        NaN       NaN         NaN   NaN    1.0
# ...          ...         ...        ...       ...         ...   ...    ...
# 235994       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 235995       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 235996       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 235997       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 235998       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 235999       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 236000       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 236001       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 236002       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 236003       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 236004       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 236005       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 236006       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 236007       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 236008       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 236009       NaN         NaN        NaN       NaN         NaN   NaN    2.0
# 236010       NaN         NaN        NaN       NaN         NaN   NaN    2.0
# 236011       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 236012       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 236013       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 236014       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 236015       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 236016       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 236017       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 236018       NaN         NaN        NaN       NaN         NaN   NaN    2.0
# 236019       NaN         NaN        NaN       NaN         NaN   NaN    2.0
# 236020       NaN         NaN        NaN       NaN         NaN   NaN    2.0
# 236021       NaN         NaN        NaN       NaN         NaN   NaN    2.0
# 236022       NaN         NaN        NaN       NaN         NaN   NaN    1.0
# 236023       NaN         NaN        NaN       NaN         NaN   NaN    NaN
#
#            ticket_ts  tot_alerts_per_tid  update_ts
# 0                NaN                 NaN        NaN
# 1                NaN                 NaN        NaN
# 2                NaN                 NaN        NaN
# 3                NaN                 NaN        NaN
# 4                NaN                 NaN        NaN
# 5                NaN                 NaN        NaN
# 6                NaN                 NaN        NaN
# 7                NaN                 NaN        NaN
# 8                NaN                 NaN        NaN
# 9                NaN                 NaN        NaN
# 10               NaN                 NaN        NaN
# 11               NaN                 NaN        NaN
# 12               NaN                 NaN        NaN
# 13               NaN                 NaN        NaN
# 14               NaN                 NaN        NaN
# 15               NaN                 NaN        NaN
# 16               NaN                 NaN        NaN
# 17               NaN                 NaN        NaN
# 18               NaN                 NaN        NaN
# 19               NaN                 NaN        NaN
# 20               NaN                 NaN        NaN
# 21               NaN                 NaN        NaN
# 22               NaN                 NaN        NaN
# 23               NaN                 NaN        NaN
# 24               NaN                 NaN        NaN
# 25               NaN                 NaN        NaN
# 26               NaN                 NaN        NaN
# 27               NaN                 NaN        NaN
# 28               NaN                 NaN        NaN
# 29               NaN                 NaN        NaN
# ...              ...                 ...        ...
# 235994           NaN                 NaN        NaN
# 235995  1.530215e+09                 1.0        NaN
# 235996           NaN                 NaN        NaN
# 235997  1.530215e+09               598.0        NaN
# 235998  1.530216e+09               598.0        NaN
# 235999  1.530216e+09               598.0        NaN
# 236000           NaN                 NaN        NaN
# 236001           NaN                 NaN        NaN
# 236002           NaN                 NaN        NaN
# 236003  1.530216e+09               598.0        NaN
# 236004           NaN                 NaN        NaN
# 236005           NaN                 NaN        NaN
# 236006           NaN                 NaN        NaN
# 236007           NaN                 NaN        NaN
# 236008           NaN                 NaN        NaN
# 236009  1.530216e+09               598.0        NaN
# 236010  1.530216e+09               598.0        NaN
# 236011  1.530216e+09               598.0        NaN
# 236012           NaN                 NaN        NaN
# 236013           NaN                 NaN        NaN
# 236014           NaN                 NaN        NaN
# 236015           NaN                 NaN        NaN
# 236016           NaN                 NaN        NaN
# 236017  1.530216e+09               598.0        NaN
# 236018           NaN                 NaN        NaN
# 236019           NaN                 NaN        NaN
# 236020           NaN                 NaN        NaN
# 236021           NaN                 NaN        NaN
# 236022           NaN                 NaN        NaN
# 236023           NaN                 NaN        NaN
#
# [236024 rows x 21 columns]

# %%
print("X_cat below")
X_cat
# Out:
# X_cat below
#             Status  Number of Records  TTA_notnull  ack_ts_notnull  \
# 0              new                1.0          0.0             0.0
# 1              new                1.0          0.0             0.0
# 2          expired                1.0          0.0             0.0
# 3          expired                1.0          0.0             0.0
# 4          expired                1.0          0.0             0.0
# 5          expired                1.0          0.0             0.0
# 6          expired                1.0          0.0             0.0
# 7          expired                1.0          0.0             0.0
# 8          expired                1.0          0.0             0.0
# 9          expired                1.0          0.0             0.0
# 10         expired                1.0          0.0             0.0
# 11         expired                1.0          0.0             0.0
# 12         expired                1.0          0.0             0.0
# 13         expired                1.0          0.0             0.0
# 14         expired                1.0          0.0             0.0
# 15         expired                1.0          0.0             0.0
# 16         expired                1.0          0.0             0.0
# 17         expired                1.0          0.0             0.0
# 18         expired                1.0          0.0             0.0
# 19         expired                1.0          0.0             0.0
# 20         expired                1.0          0.0             0.0
# 21         expired                1.0          0.0             0.0
# 22         expired                1.0          0.0             0.0
# 23         expired                1.0          0.0             0.0
# 24         expired                1.0          0.0             0.0
# 25         expired                1.0          0.0             0.0
# 26         expired                1.0          0.0             0.0
# 27         expired                1.0          0.0             0.0
# 28         expired                1.0          0.0             0.0
# 29         expired                1.0          0.0             0.0
# ...            ...                ...          ...             ...
# 235994         new                1.0          1.0             1.0
# 235995         new                1.0          1.0             1.0
# 235996         new                1.0          1.0             1.0
# 235997    Internal                1.0          1.0             1.0
# 235998    Internal                1.0          1.0             1.0
# 235999    Internal                1.0          1.0             1.0
# 236000  Automation                1.0          1.0             1.0
# 236001  Automation                1.0          1.0             1.0
# 236002  Automation                1.0          1.0             1.0
# 236003    Internal                1.0          1.0             1.0
# 236004         new                1.0          1.0             1.0
# 236005         new                1.0          1.0             1.0
# 236006         new                1.0          1.0             1.0
# 236007         new                1.0          1.0             1.0
# 236008         new                1.0          1.0             1.0
# 236009    Internal                1.0          1.0             1.0
# 236010    Internal                1.0          1.0             1.0
# 236011    Internal                1.0          1.0             1.0
# 236012         new                1.0          1.0             1.0
# 236013  Automation                1.0          1.0             1.0
# 236014  Automation                1.0          1.0             1.0
# 236015  Automation                1.0          1.0             1.0
# 236016  Automation                1.0          1.0             1.0
# 236017    Internal                1.0          1.0             1.0
# 236018         new                1.0          1.0             1.0
# 236019         new                1.0          1.0             1.0
# 236020         new                1.0          1.0             1.0
# 236021         new                1.0          1.0             1.0
# 236022         new                1.0          1.0             1.0
# 236023         NaN                NaN          NaN             NaN
#
#                          ackuid                  agent  \
# 0                           NaN                    NaN
# 1                           NaN                    NaN
# 2                           NaN                    NaN
# 3                           NaN                    NaN
# 4                           NaN                    NaN
# 5                           NaN                    NaN
# 6                           NaN                    NaN
# 7                           NaN                    NaN
# 8                           NaN                    NaN
# 9                           NaN                    NaN
# 10                          NaN                    NaN
# 11                          NaN                    NaN
# 12                          NaN                    NaN
# 13                          NaN                    NaN
# 14                          NaN                    NaN
# 15                          NaN                    NaN
# 16                          NaN                    NaN
# 17                          NaN                    NaN
# 18                          NaN                    NaN
# 19                          NaN                    NaN
# 20                          NaN                    NaN
# 21                          NaN                    NaN
# 22                          NaN                    NaN
# 23                          NaN                    NaN
# 24                          NaN                    NaN
# 25                          NaN                    NaN
# 26                          NaN                    NaN
# 27                          NaN                    NaN
# 28                          NaN                    NaN
# 29                          NaN                    NaN
# ...                         ...                    ...
# 235994                vshanbhag                    NaN
# 235995                vshanbhag                    NaN
# 235996       api_ppcc_sys_admin                    NaN
# 235997       api_ppcc_sys_admin                    NaN
# 235998       api_ppcc_sys_admin                    NaN
# 235999       api_ppcc_sys_admin                    NaN
# 236000  api_iris-consumer-agent                    NaN
# 236001  api_iris-consumer-agent                    NaN
# 236002  api_iris-consumer-agent                    NaN
# 236003       api_ppcc_sys_admin  sherlock-alert-module
# 236004               pkondappan                    NaN
# 236005               pkondappan                    NaN
# 236006               pkondappan                    NaN
# 236007               pkondappan                    NaN
# 236008               pkondappan                    NaN
# 236009       api_ppcc_sys_admin                    NaN
# 236010       api_ppcc_sys_admin                    NaN
# 236011       api_ppcc_sys_admin  sherlock-alert-module
# 236012       api_ppcc_sys_admin                    NaN
# 236013  api_iris-consumer-agent                    NaN
# 236014  api_iris-consumer-agent                    NaN
# 236015  api_iris-consumer-agent                    NaN
# 236016  api_iris-consumer-agent                    NaN
# 236017       api_ppcc_sys_admin                    NaN
# 236018                     kakh                    NaN
# 236019                     panr                    NaN
# 236020                     panr                    NaN
# 236021            vvenketaraman  sherlock-alert-module
# 236022       api_ppcc_sys_admin                    NaN
# 236023                      NaN                    NaN
#
#                                  alertid  \
# 0       577194b19826857f39d1f1807157a4bf
# 1       5cabc734283bcd1055c91f7523f58969
# 2       32ad1fd065c57ceab7de08dac715632a
# 3       bde239ff0dc8c59485c1041ae5dd378e
# 4       372acb86c73bad9f0a053a335a0e5ec7
# 5       bdb961ed9c03ef64d2bd0b9d06f0f958
# 6       dc1df4914792b0cbc2d4636f1df76822
# 7       dfdfd8594c5043e8d9c258ea0c16eed4
# 8       93dd2cb8d25bcd2ff15a81b8d6a9065c
# 9       89274d1cd8a3c1299caaa441d7f244c7
# 10      9ce1164c764b024d457d9c54eb1f4ca7
# 11      37e965cd835dc7ceeb0571acd46faa6d
# 12      9963f6a98043ba17c3cd0588815fa9d6
# 13      42b2635071799f2dff0330e5a22eb7a9
# 14      7c45e8394a9654f030d1aa56f3e7f0b6
# 15      75734a100d18ae9fd961946316137da5
# 16      0db0f68054ee651f90bd67dd67f92b62
# 17      fd4d9ea36fb3da9458715b853f7cf8e4
# 18      c6fa6c9b2221639df662e16c414aac7b
# 19      2522cd53c72ada4ab1fd7515c1faaf7c
# 20      587c58dd41c0018e8727e46265d36f5d
# 21      1b3fa3e7ad9a6a8659006b58a85a7d1a
# 22      22943e05fe92a6f3ee951e00cac8c5d1
# 23      34b6554c3f0574979e3fddd631ec912b
# 24      5ee21678dfb3db3355e152a694077c76
# 25      2e703ab53b024bedffacb4d49a172f37
# 26      0ae5d60ccbce8560cdaa673cf785aea7
# 27      74571b731d0aca7aae01d84d820bfb92
# 28      e39ba06c482cb404fcb379057f59395b
# 29      6a234ee954925080bc3815241a25edab
# ...                                  ...
# 235994  42b3826db3e87b9040c0279f6f5ca37b
# 235995  44beab5ca22529915769ba95adb48eac
# 235996  ab590e6a6738c57c6fd47da544971175
# 235997  6628fb57afb57fadab24bd3e40afe160
# 236019                                                NaN           NaN
# 236020                                                NaN           NaN
# 236021                                                NaN           NaN
# 236022                                                NaN           NaN
# 236023                                                NaN           NaN
#
#         closecode                        ...                          \
# 0             NaN                        ...
# 1             NaN                        ...
# 2            99.0                        ...
# 3            99.0                        ...
# 4            99.0                        ...
# 5            99.0                        ...
# 6            99.0                        ...
# 7            99.0                        ...
# 8            99.0                        ...
# 9            99.0                        ...
# 10           99.0                        ...
# 11           99.0                        ...
# 12           99.0                        ...
# 13           99.0                        ...
# 14           99.0                        ...
# 15           99.0                        ...
# 16           99.0                        ...
# 17           99.0                        ...
# 18           99.0                        ...
# 19           99.0                        ...
# 20           99.0                        ...
# 21           99.0                        ...
# 22           99.0                        ...
# 23           99.0                        ...
# 24           99.0                        ...
# 25           99.0                        ...
# 26           99.0                        ...
# 27           99.0                        ...
# 28           99.0                        ...
# 29           99.0                        ...
# ...           ...                        ...
# 235994        NaN                        ...
# 235995        NaN                        ...
# 235996        NaN                        ...
# 235997        1.0                        ...
# 235998        1.0                        ...
# 235999        1.0                        ...
# 236000        4.0                        ...
# 236001        4.0                        ...
# 236002        4.0                        ...
# 236003        1.0                        ...
# 236004        NaN                        ...
# 236005        NaN                        ...
# 236006        NaN                        ...
# 236007        NaN                        ...
# 236008        NaN                        ...
# 236009        1.0                        ...
# 236010        1.0                        ...
# 236011        1.0                        ...
# 236012        NaN                        ...
# 236013        4.0                        ...
# 236014        4.0                        ...
# 236015        4.0                        ...
# 236016        4.0                        ...
# 236017        1.0                        ...
# 236018        NaN                        ...
# 236019        NaN                        ...
# 236020        NaN                        ...
# 236021        NaN                        ...
# 236022        NaN                        ...
# 236023        NaN                        ...
#
#        originalseverity                                        originalurl  \
# 0                   4.0   https://sherlock.paypalcorp.com/MySherlockApp...
# 1                   4.0   https://sherlock.paypalcorp.com/MySherlockApp...
# 2                   4.0  http://nyx.paypalcorp.com:443/reports/executio...
# 3                   5.0  http://nyx.paypalcorp.com:443/reports/executio...
# 4                   4.0  http://nyx.paypalcorp.com:443/reports/executio...
# 5                   4.0  http://nyx.paypalcorp.com:443/reports/executio...
# 6                   4.0  http://nyx.paypalcorp.com:443/reports/executio...
# 7                   4.0  http://nyx.paypalcorp.com:443/reports/executio...
# 8                   5.0  https://engineering.paypalcorp.com/condor/host...
# 9                   5.0  https://engineering.paypalcorp.com/condor/host...
# 10                  4.0  http://nyx.paypalcorp.com:443/reports/executio...
# 11                  5.0  https://engineering.paypalcorp.com/condor/host...
# 12                  5.0  https://engineering.paypalcorp.com/condor/host...
# 13                  5.0  https://engineering.paypalcorp.com/condor/host...
# 14                  5.0  https://engineering.paypalcorp.com/condor/host...
# 15                  5.0  https://engineering.paypalcorp.com/condor/host...
# 16                  5.0  https://engineering.paypalcorp.com/condor/host...
# 17                  5.0  https://engineering.paypalcorp.com/condor/host...
# 18                  5.0  https://engineering.paypalcorp.com/condor/host...
# 19                  5.0  https://engineering.paypalcorp.com/condor/host...
# 20                  5.0  https://engineering.paypalcorp.com/condor/host...
# 21                  5.0  https://engineering.paypalcorp.com/condor/host...
# 22                  5.0  https://engineering.paypalcorp.com/condor/host...
# 23                  5.0  https://engineering.paypalcorp.com/condor/host...
# 24                  5.0  https://engineering.paypalcorp.com/condor/host...
# 25                  5.0  https://engineering.paypalcorp.com/condor/host...
# 26                  5.0  https://engineering.paypalcorp.com/condor/host...
# 27                  5.0  https://engineering.paypalcorp.com/condor/host...
# 28                  5.0  https://engineering.paypalcorp.com/condor/host...
# 29                  5.0  https://engineering.paypalcorp.com/condor/host...
# ...                 ...                                                ...
# 235994              4.0                                                NaN
# 235995              4.0                                                NaN
# 235996              4.0  https://engineering.paypalcorp.com/sherlock/pp...
# 235997              4.0  https://engineering.paypalcorp.com/condor/apps...
# 235998              4.0  https://engineering.paypalcorp.com/condor/apps...
# 235999              4.0  https://engineering.paypalcorp.com/condor/apps...
# 236000              5.0  https://engineering.paypalcorp.com/condor/host...
# 236001              5.0  https://engineering.paypalcorp.com/condor/host...
# 236002              5.0  https://engineering.paypalcorp.com/condor/host...
# 236003              4.0  http://sherlock-qs-vip-b.slc.paypalinc.com/q?s...
# 236004              4.0                                                NaN
# 236005              4.0                                                NaN
# 236006              4.0                                                NaN
# 236007              4.0                                                NaN
# 236008              4.0                                                NaN
# 236009              4.0  https://engineering.paypalcorp.com/condor/apps...
# 236010              4.0  https://engineering.paypalcorp.com/condor/apps...
# 236011              4.0  http://sherlock-qs-vip-b.slc.paypalinc.com/q?s...
# 236012              4.0  https://engineering.paypalcorp.com/condor/apps...
# 236013              5.0  https://engineering.paypalcorp.com/condor/host...
# 236014              5.0  https://engineering.paypalcorp.com/condor/host...
# 236015              5.0  https://engineering.paypalcorp.com/condor/host...
# 236016              5.0  https://engineering.paypalcorp.com/condor/host...
# 236017              4.0  https://engineering.paypalcorp.com/condor/apps...
# 236018              5.0  http://appworx-vip.slc.paypal.com:8084/cgi-bin...
# 236019              4.0  http://appworx-vip.slc.paypal.com:8084/cgi-bin...
# 236020              4.0  http://appworx-vip.slc.paypal.com:8084/cgi-bin...
# 236021              4.0  https://engineering.paypalcorp.com/sherlock/gr...
# 236022              4.0  https://engineering.paypalcorp.com/condor/apps...
# 236023              NaN                                                NaN
#
#        pagerdutyids severity                                   suborigin  \
# 0               NaN      4.0     PAS_CC_charge_create_FDMS_HSBC_ExtError
# 1               NaN      5.0          PAS_CC_charge_OMNIPAY_RBS_ExtError
# 2               NaN      4.0                        Needs RESTARTSERVICE
# 3               NaN      5.0                        Needs RESTARTSERVICE
# 4               NaN      4.0                        Needs RESTARTSERVICE
# 5               NaN      4.0                        Needs RESTARTSERVICE
# 6               NaN      4.0                        Needs RESTARTSERVICE
# 7               NaN      4.0                        Needs RESTARTSERVICE
# 8               NaN     99.0                                      cronus
# 9               NaN     99.0                                      cronus
# 10              NaN      4.0                        Needs RESTARTSERVICE
# 11              NaN     99.0                                      cronus
# 12              NaN     99.0                                      cronus
# 13              NaN     99.0                                      cronus
# 14              NaN     99.0                                      cronus
# 15              NaN     99.0                                      cronus
# 16              NaN     99.0                                      cronus
# 17              NaN     99.0                                      cronus
# 18              NaN     99.0                                      cronus
# 19              NaN     99.0                                      cronus
# 20              NaN     99.0                                      cronus
# 21              NaN     99.0                                      cronus
# 22              NaN     99.0                                      cronus
# 23              NaN     99.0                                      cronus
# 24              NaN     99.0                                      cronus
# 25              NaN     99.0                                      cronus
# 26              NaN     99.0                                   caldaemon
# 27              NaN     99.0                                   caldaemon
# 28              NaN     99.0                                   caldaemon
# 29              NaN     99.0                                   caldaemon
# ...             ...      ...                                         ...
# 235994          NaN      4.0                                  1069920101
# 235995          NaN      4.0                                  1069313119
# 235996          NaN      4.0                        ROOT T FAILURE SPIKE
# 235997          NaN     99.0                                pool-virtual
# 235998          NaN     99.0                                 pool-docker
# 235999          NaN      4.0                                 pool-docker
# 236000          NaN     99.0                                   caldaemon
# 236001          NaN     99.0                                   caldaemon
# 236002          NaN     99.0                                   caldaemon
# 236003          NaN      4.0                    PP-LTM-POOLDEPLETION-TIP
# 236004          NaN      4.0                                  1069990221
# 236005          NaN      4.0                                  1070001471
# 236006          NaN      4.0                                  1069997618
# 236007          NaN      4.0                                  1069998825
# 236008          NaN      4.0                                  1069995162
# 236009          NaN      4.0                                 pool-docker
# 236010          NaN      4.0                                 pool-docker
# 236011          NaN      4.0                    PP-LTM-POOLDEPLETION-TIP
# 236012          NaN     99.0                                pool-virtual
# 236013          NaN     99.0                                   caldaemon
# 236014          NaN     99.0                                   caldaemon
# 236015          NaN     99.0                                   caldaemon
# 236016          NaN     99.0                                   caldaemon
# 236017          NaN      4.0                                pool-virtual
# 236018          NaN      5.0                   PPCP_ETL_DS_CDS_DLOG_LOAD
# 236019          NaN      4.0                                  9350572.01
# 236020          NaN      4.0                                  9349262.01
# 236021          NaN      4.0  ppappmon.rootTxnCountNonBatchPerSec_ML_TIP
# 236022          NaN      4.0                                 pool-docker
# 236023          NaN      NaN                                         NaN
#
#           ticketid ticketsystem           ticketuid update_by  \
# 0              NaN          NaN                 NaN       NaN
# 1              NaN          NaN                 NaN       NaN
# 2              NaN          NaN                 NaN       NaN
# 3              NaN          NaN                 NaN       NaN
# 4              NaN          NaN                 NaN       NaN
# 5              NaN          NaN                 NaN       NaN
# 6              NaN          NaN                 NaN       NaN
# 7              NaN          NaN                 NaN       NaN
# 8              NaN          NaN                 NaN       NaN
# 9              NaN          NaN                 NaN       NaN
# 10             NaN          NaN                 NaN       NaN
# 11             NaN          NaN                 NaN       NaN
# 12             NaN          NaN                 NaN       NaN
# 13             NaN          NaN                 NaN       NaN
# 14             NaN          NaN                 NaN       NaN
# 15             NaN          NaN                 NaN       NaN
# 16             NaN          NaN                 NaN       NaN
# 17             NaN          NaN                 NaN       NaN
# 18             NaN          NaN                 NaN       NaN
# 19             NaN          NaN                 NaN       NaN
# 20             NaN          NaN                 NaN       NaN
# 21             NaN          NaN                 NaN       NaN
# 22             NaN          NaN                 NaN       NaN
# 23             NaN          NaN                 NaN       NaN
# 24             NaN          NaN                 NaN       NaN
# 25             NaN          NaN                 NaN       NaN
# 26             NaN          NaN                 NaN       NaN
# 27             NaN          NaN                 NaN       NaN
# 28             NaN          NaN                 NaN       NaN
# 29             NaN          NaN                 NaN       NaN
# ...            ...          ...                 ...       ...
# 235994         NaN          NaN                 NaN       NaN
# 235995  INC0465384           SN           vshanbhag       NaN
# 235996         NaN          NaN                 NaN       NaN
# 235997  INC0464982           SN  api_ppcc_sys_admin       NaN
# 235998  INC0464982           SN  api_ppcc_sys_admin       NaN
# 235999  INC0464982           SN  api_ppcc_sys_admin       NaN
# 236000         NaN          NaN                 NaN       NaN
# 236001         NaN          NaN                 NaN       NaN
# 236002         NaN          NaN                 NaN       NaN
# 236003  INC0464982           SN  api_ppcc_sys_admin       NaN
# 236004         NaN          NaN                 NaN       NaN
# 236005         NaN          NaN                 NaN       NaN
# 236006         NaN          NaN                 NaN       NaN
# 236007         NaN          NaN                 NaN       NaN
# 236008         NaN          NaN                 NaN       NaN
# 236009  INC0464982           SN  api_ppcc_sys_admin       NaN
# 236010  INC0464982           SN  api_ppcc_sys_admin       NaN
# 236011  INC0464982           SN  api_ppcc_sys_admin       NaN
# 236012         NaN          NaN                 NaN       NaN
# 236013         NaN          NaN                 NaN       NaN
# 236014         NaN          NaN                 NaN       NaN
# 236015         NaN          NaN                 NaN       NaN
# 236016         NaN          NaN                 NaN       NaN
# 236017  INC0464982           SN  api_ppcc_sys_admin       NaN
# 236018         NaN          NaN                 NaN       NaN
# 236019         NaN          NaN                 NaN       NaN
# 236020         NaN          NaN                 NaN       NaN
# 236021         NaN          NaN                 NaN       NaN
# 236022         NaN          NaN                 NaN       NaN
# 236023         NaN          NaN                 NaN       NaN
#
#                                                       url
# 0        https://sherlock.paypalcorp.com/MySherlockApp...
# 1        https://sherlock.paypalcorp.com/MySherlockApp...
# 2       http://nyx.paypalcorp.com:443/reports/executio...
# 3       http://nyx.paypalcorp.com:443/reports/executio...
# 4       http://nyx.paypalcorp.com:443/reports/executio...
# 5       http://nyx.paypalcorp.com:443/reports/executio...
# 6       http://nyx.paypalcorp.com:443/reports/executio...
# 7       http://nyx.paypalcorp.com:443/reports/executio...
# 8       https://engineering.paypalcorp.com/condor/host...
# 9       https://engineering.paypalcorp.com/condor/host...
# 10      http://nyx.paypalcorp.com:443/reports/executio...
# 11      https://engineering.paypalcorp.com/condor/host...
# 12      https://engineering.paypalcorp.com/condor/host...
# 13      https://engineering.paypalcorp.com/condor/host...
# 14      https://engineering.paypalcorp.com/condor/host...
# 15      https://engineering.paypalcorp.com/condor/host...
# 16      https://engineering.paypalcorp.com/condor/host...
# 17      https://engineering.paypalcorp.com/condor/host...
# 18      https://engineering.paypalcorp.com/condor/host...
# 19      https://engineering.paypalcorp.com/condor/host...
# 20      https://engineering.paypalcorp.com/condor/host...
# 21      https://engineering.paypalcorp.com/condor/host...
# 22      https://engineering.paypalcorp.com/condor/host...
# 23      https://engineering.paypalcorp.com/condor/host...
# 24      https://engineering.paypalcorp.com/condor/host...
# 25      https://engineering.paypalcorp.com/condor/host...
# 26      https://engineering.paypalcorp.com/condor/host...
# 27      https://engineering.paypalcorp.com/condor/host...
# 28      https://engineering.paypalcorp.com/condor/host...
# 29      https://engineering.paypalcorp.com/condor/host...
# ...                                                   ...
# 235994                                                NaN
# 235995                                                NaN
# 235996  https://engineering.paypalcorp.com/sherlock/pp...
# 235997  https://engineering.paypalcorp.com/condor/apps...
# 235998  https://engineering.paypalcorp.com/condor/apps...
# 235999  https://engineering.paypalcorp.com/condor/apps...
# 236000  https://engineering.paypalcorp.com/condor/host...
# 236001  https://engineering.paypalcorp.com/condor/host...
# 236002  https://engineering.paypalcorp.com/condor/host...
# 236003  http://sherlock-qs-vip-b.slc.paypalinc.com/q?s...
# 236004                                                NaN
# 236005                                                NaN
# 236006                                                NaN
# 236007                                                NaN
# 236008                                                NaN
# 236009  https://engineering.paypalcorp.com/condor/apps...
# 236010  https://engineering.paypalcorp.com/condor/apps...
# 236011  http://sherlock-qs-vip-b.slc.paypalinc.com/q?s...
# 236012  https://engineering.paypalcorp.com/condor/apps...
# 236013  https://engineering.paypalcorp.com/condor/host...
# 236014  https://engineering.paypalcorp.com/condor/host...
# 236015  https://engineering.paypalcorp.com/condor/host...
# 236016  https://engineering.paypalcorp.com/condor/host...
# 236017  https://engineering.paypalcorp.com/condor/apps...
# 236018  http://appworx-vip.slc.paypal.com:8084/cgi-bin...
# 236019  http://appworx-vip.slc.paypal.com:8084/cgi-bin...
# 236020  http://appworx-vip.slc.paypal.com:8084/cgi-bin...
# 236021  https://engineering.paypalcorp.com/sherlock/gr...
# 236022  https://engineering.paypalcorp.com/condor/apps...
# 236023                                                NaN
#
# [236024 rows x 39 columns]

# %% [markdown]
# This function plots boxplots of each numerical column, each column getting a boxplot with and without outliers (outliers are defined as any values above 1.5 times the interquartile range).

# %%
def plot_num_val(X, max_r, max_c):
    num_fig = math.ceil(X.shape[1] / (max_r * max_c))
    figs = [0] * num_fig * 2
    L_Xn = list(X)

    for i in range(0, num_fig):
        sub_r = max_r if math.ceil(math.sqrt(int(X.shape[1]))) > max_r else math.ceil(math.sqrt(int(X.shape[1])))
        sub_c = max_c if math.ceil(int(X.shape[1]) / sub_r) > max_c else math.ceil(int(X.shape[1]) / sub_r)
        figs[i] = plt.subplots(nrows=sub_r, ncols=sub_c, figsize = (15,15))
        plt.suptitle('Numerical Plots #' + str(i + 1))
        batch = 1
        curr_dim = sub_r * sub_c
        for j in range(i * curr_dim, (i + 1) * curr_dim):
            if j >= len(L_Xn):
                break
            plt.subplot(sub_r, sub_c, batch)
            sns.boxplot(data=X[L_Xn[j]])  # , kind = 'box')
            plt.xticks(rotation=-45, ha = 'left')
            plt.tight_layout()
            plt.tick_params(axis='both', which='major', labelsize=6)
            plt.xlabel(L_Xn[j])
            plt.tight_layout(rect=[0, 0.03, 1, 0.95])
            
            batch += 1
            if batch > (sub_c * sub_r):
                break
            
        plt.savefig(VIZ_PATH + "NUMPLOT_" + str(i) + ".png", format="png")
        print("All Done with plot #" + str(i + 1))

    for i in range(0, num_fig):
        sub_r = max_r if math.ceil(math.sqrt(int(X.shape[1]))) > max_r else math.ceil(math.sqrt(int(X.shape[1])))
        sub_c = max_c if math.ceil(int(X.shape[1]) / sub_r) > max_c else math.ceil(int(X.shape[1]) / sub_r)
        figs[i + num_fig] = plt.subplots(nrows=sub_r, ncols=sub_c, figsize = (15,15))
        plt.suptitle('Numerical Plots #' + str(i + 1) + " [NO OUTLIERS]")
        batch = 1
        curr_dim = sub_r * sub_c
        for j in range(i * curr_dim, (i + 1) * curr_dim):
            if j >= len(L_Xn):
                break
            plt.subplot(sub_r, sub_c, batch)
            sns.boxplot(data=X[L_Xn[j]], showfliers = False)
            plt.xticks(rotation=-45, ha = 'left')
            plt.tight_layout()
            plt.tick_params(axis='both', which='major', labelsize=6)
            plt.xlabel(str(L_Xn[j]) + " [No Outliers]")
            plt.tight_layout(rect=[0, 0.03, 1, 0.95])
            batch += 1
            if batch > (sub_c * sub_r):
                break

if X_numeric.shape[1] > 0:
    print("Plotting...")
    plot_num_val(X_numeric, 4, 4)
# Out:
# Plotting...
# All Done with plot #1
# All Done with plot #2

# %%
def data_clean(X, cat_data_valCounts, col_stats, n_freq, f_thresh, m_thresh):
    n_rows = X.shape[0]
    dropped_cols = list()
    for c in X:
        #print(cat_data_valCounts[c].head(n_freq).iloc[0])
        freq_sum = float(cat_data_valCounts[c].head(n_freq).iloc[0].sum()) if c in cat_data_valCounts.keys() else n_rows
        if freq_sum / n_rows < f_thresh or float(col_stats.loc["missing", c]) / n_rows > m_thresh:
            X.drop(labels=[c], axis = 1, inplace=True)
            print("Dropped \"" + str(c) + "\"")
            dropped_cols.append(c)
    return X, dropped_cols

X_num_cleaned, X_cat_cleaned = pd.DataFrame(), pd.DataFrame()
if X_numeric.shape[1] > 0:
    n_freq = 5
    FREQ_THRESH = 0.3
    MISS_THRESH = 0.5
    print("Cleaning Numericals...\n")
    X_num_cleaned, num_dropped = data_clean(X_numeric, cat_data_valCounts, col_stats, n_freq, FREQ_THRESH, MISS_THRESH)
    print("\n\nCleaning Categoricals...\n")
    X_cat_cleaned, cat_dropped = data_clean(X_cat, cat_data_valCounts, col_stats, n_freq, FREQ_THRESH, MISS_THRESH)
# Out:
# Cleaning Numericals...
#
# Dropped "proxy_ts"
# Dropped "proxyip"
# Dropped "proxyname"
# Dropped "senderip"
# Dropped "sendername"
# Dropped "server_ts"
# Dropped "serverip"
# Dropped "servername"
# Dropped "tags"
# Dropped "ticket_ts"
# Dropped "tot_alerts_per_tid"
# Dropped "update_ts"
#
#
# Cleaning Categoricals...
#
# Dropped "ackuid"
# Dropped "agent"
# Dropped "alertid"
# Dropped "clear_ts"
# Dropped "close_message"
# Dropped "colo"
# Dropped "component"
# Dropped "display_date"
# Dropped "displayuid"
# Dropped "groupid"
# Dropped "hostname"
# Dropped "identifier"
# Dropped "kblink"
# Dropped "lastgroupid"
# Dropped "message"
# Dropped "message_md5"
# Dropped "origin"
# Dropped "originalgroupid"
# Dropped "originalhostname"
# Dropped "originalmessage"
# Dropped "originalmessage_md5"
# Dropped "originalurl"
# Dropped "pagerdutyids"
# Dropped "suborigin"
# Dropped "ticketid"
# Dropped "ticketsystem"
# Dropped "ticketuid"
# Dropped "update_by"
# Dropped "url"
#             Status  Number of Records  TTA_notnull  ack_ts_notnull  closecode  \
# 0              new                1.0          0.0             0.0        NaN
# 1              new                1.0          0.0             0.0        NaN
# 2          expired                1.0          0.0             0.0       99.0
# 3          expired                1.0          0.0             0.0       99.0
# 4          expired                1.0          0.0             0.0       99.0
# 5          expired                1.0          0.0             0.0       99.0
# 6          expired                1.0          0.0             0.0       99.0
# 7          expired                1.0          0.0             0.0       99.0
# 8          expired                1.0          0.0             0.0       99.0
# 9          expired                1.0          0.0             0.0       99.0
# 10         expired                1.0          0.0             0.0       99.0
# 11         expired                1.0          0.0             0.0       99.0
# 12         expired                1.0          0.0             0.0       99.0
# 13         expired                1.0          0.0             0.0       99.0
# 14         expired                1.0          0.0             0.0       99.0
# 15         expired                1.0          0.0             0.0       99.0
# 16         expired                1.0          0.0             0.0       99.0
# 17         expired                1.0          0.0             0.0       99.0
# 18         expired                1.0          0.0             0.0       99.0
# 19         expired                1.0          0.0             0.0       99.0
# 20         expired                1.0          0.0             0.0       99.0
# 21         expired                1.0          0.0             0.0       99.0
# 22         expired                1.0          0.0             0.0       99.0
# 23         expired                1.0          0.0             0.0       99.0
# 24         expired                1.0          0.0             0.0       99.0
# 25         expired                1.0          0.0             0.0       99.0
# 26         expired                1.0          0.0             0.0       99.0
# 27         expired                1.0          0.0             0.0       99.0
# 28         expired                1.0          0.0             0.0       99.0
# 29         expired                1.0          0.0             0.0       99.0
# ...            ...                ...          ...             ...        ...
# 235994         new                1.0          1.0             1.0        NaN
# 235995         new                1.0          1.0             1.0        NaN
# 235996         new                1.0          1.0             1.0        NaN
# 235997    Internal                1.0          1.0             1.0        1.0
# 235998    Internal                1.0          1.0             1.0        1.0
# 235999    Internal                1.0          1.0             1.0        1.0
# 236000  Automation                1.0          1.0             1.0        4.0
# 236001  Automation                1.0          1.0             1.0        4.0
# 236002  Automation                1.0          1.0             1.0        4.0
# 236003    Internal                1.0          1.0             1.0        1.0
# 236004         new                1.0          1.0             1.0        NaN
# 236005         new                1.0          1.0             1.0        NaN
# 236006         new                1.0          1.0             1.0        NaN
# 236007         new                1.0          1.0             1.0        NaN
# 236008         new                1.0          1.0             1.0        NaN
# 236009    Internal                1.0          1.0             1.0        1.0
# 236010    Internal                1.0          1.0             1.0        1.0
# 236011    Internal                1.0          1.0             1.0        1.0
# 236012         new                1.0          1.0             1.0        NaN
# 236013  Automation                1.0          1.0             1.0        4.0
# 236014  Automation                1.0          1.0             1.0        4.0
# 236015  Automation                1.0          1.0             1.0        4.0
# 236016  Automation                1.0          1.0             1.0        4.0
# 236017    Internal                1.0          1.0             1.0        1.0
# 236018         new                1.0          1.0             1.0        NaN
# 236019         new                1.0          1.0             1.0        NaN
# 236020         new                1.0          1.0             1.0        NaN
# 236021         new                1.0          1.0             1.0        NaN
# 236022         new                1.0          1.0             1.0        NaN
# 236023         NaN                NaN          NaN             NaN        NaN
#
#                        closeuid  dsp_ts_notnull  lastseverity  \
# 0                           NaN             1.0           4.0
# 1                           NaN             1.0           4.0
# 2                       expired             1.0           4.0
# 3                       expired             1.0           5.0
# 4                       expired             1.0           4.0
# 5                       expired             1.0           4.0
# 6                       expired             1.0           4.0
# 7                       expired             1.0           4.0
# 8                       expired             1.0           5.0
# 9                       expired             1.0           5.0
# 10                      expired             1.0           4.0
# 11                      expired             1.0           5.0
# 12                      expired             1.0           5.0
# 13                      expired             1.0           5.0
# 14                      expired             1.0           5.0
# 15                      expired             1.0           5.0
# 16                      expired             1.0           5.0
# 17                      expired             1.0           5.0
# 18                      expired             1.0           5.0
# 19                      expired             1.0           5.0
# 20                      expired             1.0           5.0
# 21                      expired             1.0           5.0
# 22                      expired             1.0           5.0
# 23                      expired             1.0           5.0
# 24                      expired             1.0           5.0
# 25                      expired             1.0           5.0
# 26                      expired             1.0           5.0
# 27                      expired             1.0           5.0
# 28                      expired             1.0           5.0
# 29                      expired             1.0           5.0
# ...                         ...             ...           ...
# 235994                      NaN             1.0           4.0
# 235995                      NaN             1.0           4.0
# 235996                      NaN             1.0           4.0
# 235997       api_ppcc_sys_admin             1.0           4.0
# 235998       api_ppcc_sys_admin             1.0           4.0
# 235999       api_ppcc_sys_admin             1.0           4.0
# 236000  api_iris-consumer-agent             1.0           5.0
# 236001  api_iris-consumer-agent             1.0           5.0
# 236002  api_iris-consumer-agent             1.0           5.0
# 236003       api_ppcc_sys_admin             1.0           4.0
# 236004                      NaN             1.0           4.0
# 236005                      NaN             1.0           4.0
# 236006                      NaN             1.0           4.0
# 236007                      NaN             1.0           4.0
# 236008                      NaN             1.0           4.0
# 236009       api_ppcc_sys_admin             1.0          99.0
# 236010       api_ppcc_sys_admin             1.0          99.0
# 236011       api_ppcc_sys_admin             1.0           4.0
# 236012                      NaN             1.0           4.0
# 236013  api_iris-consumer-agent             1.0           5.0
# 236014  api_iris-consumer-agent             1.0           5.0
# 236015  api_iris-consumer-agent             1.0           5.0
# 236016  api_iris-consumer-agent             1.0           5.0
# 236017       api_ppcc_sys_admin             1.0           4.0
# 236018                      NaN             1.0           5.0
# 236019                      NaN             1.0           4.0
# 236020                      NaN             1.0           4.0
# 236021                      NaN             1.0           4.0
# 236022                      NaN             1.0           4.0
# 236023                      NaN             NaN           NaN
#
#         originalseverity  severity
# 0                    4.0       4.0
# 1                    4.0       5.0
# 2                    4.0       4.0
# 3                    5.0       5.0
# 4                    4.0       4.0
# 5                    4.0       4.0
# 6                    4.0       4.0
# 7                    4.0       4.0
# 8                    5.0      99.0
# 9                    5.0      99.0
# 10                   4.0       4.0
# 11                   5.0      99.0
# 12                   5.0      99.0
# 13                   5.0      99.0
# 14                   5.0      99.0
# 15                   5.0      99.0
# 16                   5.0      99.0
# 17                   5.0      99.0
# 18                   5.0      99.0
# 19                   5.0      99.0
# 20                   5.0      99.0
# 21                   5.0      99.0
# 22                   5.0      99.0
# 23                   5.0      99.0
# 24                   5.0      99.0
# 25                   5.0      99.0
# 26                   5.0      99.0
# 27                   5.0      99.0
# 28                   5.0      99.0
# 29                   5.0      99.0
# ...                  ...       ...
# 235994               4.0       4.0
# 235995               4.0       4.0
# 235996               4.0       4.0
# 235997               4.0      99.0
# 235998               4.0      99.0
# 235999               4.0       4.0
# 236000               5.0      99.0
# 236001               5.0      99.0
# 236002               5.0      99.0
# 236003               4.0       4.0
# 236004               4.0       4.0
# 236005               4.0       4.0
# 236006               4.0       4.0
# 236007               4.0       4.0
# 236008               4.0       4.0
# 236009               4.0       4.0
# 236010               4.0       4.0
# 236011               4.0       4.0
# 236012               4.0      99.0
# 236013               5.0      99.0
# 236014               5.0      99.0
# 236015               5.0      99.0
# 236016               5.0      99.0
# 236017               4.0       4.0
# 236018               5.0       5.0
# 236019               4.0       4.0
# 236020               4.0       4.0
# 236021               4.0       4.0
# 236022               4.0       4.0
# 236023               NaN       NaN
#
# [236024 rows x 10 columns]

# %%
def plot_cat_val(cat_data_valCounts, n_rows, n_freq, max_r, max_c):
    cat_len = len(cat_data_valCounts.keys())
    if (cat_len > 0):

        sub_cat_r = max_r if math.ceil(math.sqrt(cat_len)) > max_r else math.ceil(math.sqrt(cat_len))
        sub_cat_c = max_c if math.ceil(cat_len / sub_cat_r) > max_c else math.ceil(cat_len / sub_cat_r)
        num_fig = math.ceil(float(cat_len) / (max_r * max_c))
        cdvc_keys = list(cat_data_valCounts.keys())
        curr_dim = sub_cat_c * sub_cat_r
        figs_c = [0] * num_fig
        for f_c in range(0, num_fig):
            sub_cat_r = max_r if math.ceil(math.sqrt(cat_len)) > max_r else math.ceil(math.sqrt(cat_len))
            sub_cat_c = max_c if math.ceil(cat_len / sub_cat_r) > max_c else math.ceil(cat_len / sub_cat_r)
            figs_c[f_c] = plt.subplots(nrows=sub_cat_r, ncols=sub_cat_c, figsize=(15,15))
            batch = 1
            for i in range(f_c * curr_dim, (f_c + 1) * curr_dim):
                if i >= cat_len:
                    break
                toPlt = cat_data_valCounts[cdvc_keys[i]].head(n_freq)
                plt.subplot(sub_cat_r, sub_cat_c, batch)
                plt.suptitle("Categorical Plot #" + str(f_c + 1))
                plt.bar(toPlt.index, toPlt / float(n_rows))
                plt.xticks(rotation=-45, ha = 'left')
                plt.tick_params(axis='both', which='major', labelsize=6)
                batch += 1
            print("done with plot #" + str(f_c + 1))
    else:
        print("No categories so no category frequency graph.")

n_freq = 5
if X_cat.shape[1] > 0:
    plot_cat_val(cat_data_valCounts, X.shape[0], n_freq, 4, 4)
# Out:
# done with plot #1
# done with plot #2
# done with plot #3

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i + 1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop


def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

def plot_num_hm(X_num):
    sns.set(style="white")
    corr = X_num.corr()
    mask = np.zeros_like(corr, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True
    fig_corr1, ax_corr1 = plt.subplots(figsize=(15,15))
    cmap = sns.diverging_palette(220, 10, as_cmap=True)
    plt.suptitle("Numerical Correlations Heatmap")

    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
    plt.xticks(rotation=-45, ha = 'left')
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.savefig(VIZ_PATH + "CORRELATION_HEATMAP.png", format="png")

if X_numeric.shape[1] > 0:
    plot_num_hm(X_num_cleaned)

# %%
def plot_pairwise_corr(X_num, k):
    print("Top Absolute Correlations")
    top_corr = get_top_abs_correlations(X_num, k)
    top_corr.index = list(map(str, top_corr.index.values))
    fig_pc, ax_pc = plt.subplots(figsize=(15,15))
    plt.bar(top_corr.index, top_corr)
    plt.title("Top Absolute Correlations [ALL COLUMNS]")
    plt.xticks(rotation=-45, ha = 'left')
    plt.ylabel("Absolute Pearson Correlation Coefficient")
    plt.xlabel("Column Pairs")
    plt.tick_params(axis='both', which='major')
    plt.tight_layout()
    plt.savefig(VIZ_PATH + "PAIRWISE_CORR.png", format="png")
    
if X_numeric.shape[1] > 0:
    k = 15
    plot_pairwise_corr(X_num_cleaned, k)
# Out:
# Top Absolute Correlations

# %%
def plot_target_corr(targetCol, X_num):
    target_corr = X_num.corrwith(X_num[targetCol]).abs()
    target_corr = target_corr.drop([targetCol])
    fig_tc, ax_tc = plt.subplots(figsize=(15,15))
    plt.title("Top Absolute Correlations [TARGET = \'" + targetCol + "\']")
    plt.xticks(rotation=-45, ha = 'left')
    plt.ylabel("Absolute Pearson Correlation Coefficient")
    plt.xlabel("Columns")
    plt.tick_params(axis='both', which='major', labelsize=10)
    plt.bar(target_corr.index, target_corr)
    plt.tight_layout()
    plt.savefig(VIZ_PATH + "TARGET_CORR.png", format="png")

if X_numeric.shape[1] > 0:
    target = "tally" #change to desired column name
    plot_target_corr(target, X_numeric)

# %%
######################### CREATE CATEGORICAL VS NUMERICAL PLOTS ###################################
def map_col(X, cat_data_valCounts, n_freq):
    col_mappings = dict(dict())
    for c in X:
        if c in cat_data_valCounts.keys():
            map_build = {}
            cnt = 1
            for catcol in list(cat_data_valCounts[c].head(n_freq).index):
                map_build[catcol] = cnt
                cnt += 1
            col_mappings[c] = map_build
    pp.pprint(col_mappings)
    return col_mappings

def convert_cat_col(X_cat, col_mappings, cat_data_valCounts, n_freq):
    X_catmap = X_cat
    for c in X_cat:
        X_catmap[c] = X_cat[c].apply(
            lambda x: col_mappings[c][x] if x in cat_data_valCounts[c].head(n_freq).index else 0)
    return X_catmap


def plot_cat_vs_num_corr(X_catmap, X_num, color_ordered, cat_data_valCounts, n_freq, max_r, max_c):
    cat_dim, num_dim = X_catmap.shape[1], X_num.shape[1]
    cat_dim_fig, num_dim_fig = math.ceil(float(cat_dim) / max_c),  math.ceil(float(num_dim) / max_r)
    cat_names, num_names = list(X_catmap), list(X_num)
    # print(cat_dim_fig)
    # print(num_dim_fig)
    #figs_cn = [0] * cat_dim_fig * num_dim_fig
    OS_order = range(1, n_freq + 1)

    X_numeric_nonan = X_num.fillna(0)
    batch = 1
    print("begin plotting...")
    for f_c in range(0, cat_dim_fig):
        for f_n in range(0, num_dim_fig):
            #prepare batch of data to plot
            num_max = (f_n + 1) * max_r if (f_n + 1) * max_r < X_num.shape[1] else X_num.shape[1] - 1
            cat_max = (f_c + 1) * max_c if (f_c + 1) * max_c < X_catmap.shape[1] else X_catmap.shape[1] - 1
            X_num_batch = X_numeric_nonan.loc[:, num_names[f_n * max_r]:num_names[num_max]]
            X_cat_batch = X_catmap.loc[:, cat_names[f_c * max_c]:cat_names[cat_max]]

            X_batch = pd.concat([X_num_batch, X_cat_batch], axis=1, sort=False)

            #begin plotting
            #figs_cn[batch - 1] = plt.subplots()
            sns.set()
            sns.set_style("ticks")
            sns.set_style('darkgrid')
            print("Creating categorical vs. numerical correlation matrix graph...")
            g = sns.PairGrid(X_batch, x_vars=list(X_cat_batch), y_vars=list(X_num_batch))
            g.map(sns.stripplot, order=OS_order, jitter=0.5, s=5, alpha=0.3, palette=color_ordered)
            g.fig.suptitle("Categorical vs. Numerical Plots #" + str(batch))
            for j in range(0, len(list(X_cat_batch))):
                g.axes[0, j].set_xticklabels(list(cat_data_valCounts[list(X_cat_batch)[j]].head(n_freq).index))
            plt.rcParams["xtick.labelsize"] = 4
            for ax in g.axes.flat:
                for label in ax.get_yticklabels():
                    label.set_rotation(0)
            for ax in g.axes.flat:
                for label in ax.get_xticklabels():
                    label.set_rotation(90)
            plt.savefig(VIZ_PATH + "CAT_VS_NUM_CORR_PLOT_CATBATCH_" + str(f_c) + "_NUMBATCH_" + str(f_n) + ".png", format="png")
            plt.tight_layout(rect=[0, 0.03, 1, 0.95])
            batch += 1
    print("Done!")

#applying mapping takes a while since every datapoint is encountered and changed
if (len(list(X_cat_cleaned)) * len(list(X_num_cleaned))) > 0:
    color_ordered = ['dodgerblue', 'brown', 'black', 'indianred', 'blue', 'darkviolet', 'darkgoldenrod', 'darkcyan',
                         'green', 'red', 'darkorange', 'olive', 'orchid', 'gray', 'yellowgreen', 'sandybrown']
    print("mapping...")
    col_mapping = map_col(X_cat_cleaned, cat_data_valCounts, n_freq)
    print("applying mapping...")
    X_catmap = convert_cat_col(X_cat_cleaned, col_mapping, cat_data_valCounts, n_freq)
    print("done mapping.")
    plot_cat_vs_num_corr(X_cat_cleaned, X_num_cleaned, color_ordered, cat_data_valCounts, n_freq, 10, 10)
    
else:
    print("No categories and/or numerical columns, so no category vs. numerical plot.")
# Out:
# mapping...
# {'Number of Records': {1.0: 1},
#  'Status': {'Automation': 4,
#             'Internal': 2,
#             'QuickTicket-Self-Recovered': 5,
#             'expired': 1,
#             'new': 3},
#  'TTA_notnull': {0.0: 2, 1.0: 1},
#  'ack_ts_notnull': {0.0: 2, 1.0: 1},
#  'closecode': {1.0: 2, 2.0: 5, 4.0: 3, 51.0: 4, 99.0: 1},
#  'closeuid': {'api_iris-consumer-agent': 3,
#               'api_ppcc_sys_admin': 2,
#               'bransom': 5,
#               'expired': 1,
#               'ticketsync': 4},
#  'dsp_ts_notnull': {1.0: 1},
#  'lastseverity': {0.0: 3, 3.0: 4, 4.0: 2, 5.0: 1, 99.0: 5},
#  'originalseverity': {0.0: 3, 2.0: 5, 3.0: 4, 4.0: 2, 5.0: 1},
#  'severity': {0.0: 5, 3.0: 4, 4.0: 2, 5.0: 3, 99.0: 1}}
# applying mapping...
# done mapping.
# begin plotting...
# Creating categorical vs. numerical correlation matrix graph...
# Done!

# %%
def plot_date_val(X_date, X_num):
    figs = [0] * len(list(X_date)) * 2
    i = 0
    for d in X_date:
        Xd = X_date[d].dropna()
        try:
            gbc_d = pd.DataFrame(Xd.groupby(by=[Xd.dt.day.rename('d'), Xd.dt.month.rename('m'), Xd.dt.year.rename('y')]).count())
        except AttributeError:
            pass
        try:
            gbc_m = pd.DataFrame(Xd.groupby(by=[Xd.dt.month.rename('m'), Xd.dt.year.rename('y')]).count())
        except AttributeError:
            pass
        #plot day granularity
        new_index = [gbc_d.index.map('{0[1]}/{0[0]}/{0[2]}'.format)]        
        gbc_d = pd.DataFrame(gbc_d.reset_index().drop(['d', 'm', 'y'], axis=1))
        gbc_d.index = new_index
        gbc_d.index = gbc_d.index.map(pd.to_datetime)
        figs[i] = plt.subplots(figsize=(15,15))
        plt.suptitle("Column \"" + d + "\" - Datetime Plot By Day")
        plt.xticks(rotation=-45, ha = 'left')
        plt.yticks(rotation=0)
        plt.tick_params(axis='both', which='major', labelsize=12)
        plt.tight_layout(rect=[0, 0.03, 1, 0.95])
        plt.plot(gbc_d.sort_index())
        
        #plot month granularity
        new_index = [gbc_m.index.map('{0[0]}/{0[1]}'.format)]
        gbc_m = pd.DataFrame(gbc_m.reset_index().drop(['m', 'y'], axis=1))
        gbc_m.index = new_index
        gbc_m.index = gbc_m.index.map(pd.to_datetime)
        figs[i + 1] = plt.subplots(figsize=(15,15))
        plt.suptitle("Column \"" + d + "\" - Datetime Plot By Month")
        plt.xticks(rotation=-45, ha = 'left')
        plt.yticks(rotation=0)
        plt.tick_params(axis='both', which='major', labelsize=12)
        plt.tight_layout(rect=[0, 0.03, 1, 0.95])
        plt.plot(gbc_m.sort_index())
        i += 2
if X_date.shape[1] > 0:        
    print("Plotting...")
    plot_date_val(X_date, X_num_cleaned)
    print("Done Plotting.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-de31d7706c04> in <module>()
#      38         plt.plot(gbc_m.sort_index())
#      39         i += 2
# ---> 40 if X_date.shape[1] > 0:
#      41     print("Plotting...")
#      42     plot_date_val(X_date, X_num_cleaned)
#
# NameError: name 'X_date' is not defined
